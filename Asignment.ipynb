# %%
# 1. Write a Python program to create a class called "Person" with properties for name, age and country. Include a method to display the person's details. 
# Create two instances of the 'Person' class and display their details.
class person():
    def __init__(self,name,age,country):
        self.name = name
        self.age = age
        self.country = country
    def show_info(self):
        print(f"Your Name is {self.name} age is {self.age} and your country is {self.country}")
p1 = person("Ali",19,"Pakistan")
p1.show_info()
# Out:
# Your Name is Ali age is 19 and your country is Pakistan

# %%
# 2. Write a Python program to create a class called 'Rectangle' with properties for width and height. 
# Include two methods to calculate rectangle area and perimeter. Create an instance of the 'Rectangle' class and calculate its area and perimeter.
class Rectangle():
    def __init__(self,width,Height):
        self.width = width
        self.Height = Height
    def area(self):
        area = self.width * self.Height
        print(f"Area is {area}")
    def perimiter(self):
        perim = (self.width + self.Height) * 2
        print(f"Perimeter is {perim}")
r1 = Rectangle(2,3)
r1.area()
r1.perimiter()
# Out:
# Area is 6
# Perimeter is 10

# %%
# 3. Write a Python program that creates a class called 'Vehicle' with properties for make, model, and year. Include a method to display vehicle details. 
# Create a subclass called 'Car' that inherits from the 'Vehicle' class and includes an additional property for the number of doors.
# Override the display method to include the number of doors.
class Vheicle():
    def __init__(self,make,model,year):
        self.make = make
        self.model = model
        self.year = year
    def details(self):
        print(f"Car Make is {self.make} \nModel is {self.model} \nYear is {self.year}")
class Car(Vheicle):
    def __init__(self,doors,make,model,year):
        super().__init__(make,model,year)
        self.doors = doors          
Ca = Car(2,"BMW","M5",2026)
Ca.details()
# Out:
# Car Make is BMW
# Model is M5
# Year is 2026

# %%
# 4. Write a Python program that creates a class called "BankAccount" with properties for account number and balance. 
# Include methods to deposit and withdraw money from the account. Create some instances of the "BankAccount" class, deposit some money, 
# and withdraw a portion of it.
acc = {} 
class Bank_Acc():
    acc = {} 
    def create_account(self):
        Username = input("Enter Username: ")
        Password = input("Enter Password: ")
        Acc_No = int(input("Input Acc_No:"))
        if Acc_No in acc.keys():
            print("Acc_No Alredy Exists")
        else:
            acc.setdefault(Acc_No, [Username,Password,0])
            print(f"Adding {acc[Acc_No]}...")
    def deposit(self):
        Acc_Nos = int(input("Enter Valid Acc_No: "))
        if Acc_Nos in acc.keys():
            Password = input("Enter Password: ")
            if Password == acc[Acc_Nos][1]:
                print("Authenticated")
                Cash = float(input("Enter How Many Money Want To Deposit:"))
                acc[Acc_Nos][2] += Cash
                print("Transaction Sucssesful")
            else:
                print(f"Incorrect Password = {Password}")
        else:
            print(f"{Acc_Nos} Don't Exist")
    def Withdrawl(self):
        Acc_Nos = int(input("Enter Valid Acc_No: "))
        if Acc_Nos in acc.keys():
            Password = input("Enter Password: ")
            if Password == acc[Acc_Nos][1]:
                print("Authenticated")
                Cash = float(input("Enter How Many Money Want To Withdraw:"))
                if Cash <= 0:
                    print("Minimum Limit is 1Rs")
                elif Cash >= acc[Acc_Nos][2]:
                    print("Cash Not In Acc")
                else:
                    acc[Acc_Nos][2] -= Cash
                    print(f"deposited {Cash} Remaining Balance: {acc[Acc_Nos][2]}")
            else:
                print(f"Incorrect Password = {Password}")
        else:
            print(f"{Acc_Nos} Don't Exist")
b1 = Bank_Acc()
b1.create_account()
b1.deposit()
b1.Withdrawl()
# Out:
# Enter Username:  nu
# Enter Password:  12
# Input Acc_No: 3
# Adding ['nu', '12', 0]...
# Enter Valid Acc_No:  3
# Enter Password:  12
# Authenticated
# Enter How Many Money Want To Deposit: 1000
# Transaction Sucssesful
# Enter Valid Acc_No:  3
# Enter Password:  12
# Authenticated
# Enter How Many Money Want To Withdraw: 500
# deposited 500.0 Remaining Balance: 500.0

# %%
# 5. Write a Python program that creates a class called 'Shape' with a method to calculate the area. 
# Create two subclasses, 'Circle' and 'Triangle', that inherit from the 'Shape' class and override the area calculation method. 
# Create an instance of the 'Circle' class and calculate its area. Similarly, do the same for the 'Triangle' class.
class Shape():
    def area():
        pass
class Triangle(Shape):
    def __init__(self,base,height):
        self.base = base
        self.height = height
    def area(self):
        area = 1/2 * self.base * self.height
        print(f"Triangle Area is {area}")
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        pie = 3.142
        areas = pie * self.radius ** 2 
        print(f"Circle area is {areas}")
T1 = Triangle(12,34)
c1 = Circle(9)
T1.area()
c1.area()
# Out:
# Triangle Area is 204.0
# Circle area is 254.50199999999998

# %%
# 6. Write a Python program that creates a class called 'Employee' with properties for name and salary. 
# Include a method to calculate annual salary. Create a subclass called 'Manager' that inherits from the 'Employee' class and adds an
# additional property for department. Override the annual salary calculation method to include bonuses for managers. Create two instances of the 
# 'Manager' class and calculate their annual salary.


class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def annual_salary(self):
        annual = self.salary * 12
        print(f"{self.name}'s Annual Salary is {annual}")


class Manager(Employee):
    def __init__(self, name, salary, department):
        super().__init__(name, salary)
        self.department = department

    def annual_salary(self):
        bonus = 30000
        bonus_months = 5
        total_bonus = bonus * bonus_months
        annual = (self.salary * 12) + total_bonus
        print(f"{self.name}'s Annual Salary (with bonus) is {annual}")


e1 = Employee("Asif", 90000)
m1 = Manager("Kashif", 300000, "Gulshan")

e1.annual_salary()
m1.annual_salary()
# Out:
# Asif's Annual Salary is 1080000
# Kashif's Annual Salary (with bonus) is 3750000

# %%
# 7. Write a Python program that creates a class `Book` with properties for title, author, and publication year.
# Include a method to display book details. Create a subclass called 'Ebook' that inherits from the 'Book' class and includes an additional property 
# for book price. Override the display method to include the book price. Create an instance of the 'Ebook' class and display its details.


class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def display_details(self):
        print("Book Details")
        print(f"Title : {self.title}")
        print(f"Author  : {self.author}")
        print(f"Published Year  : {self.year}")


class Ebook(Book):
    def __init__(self, title, author, year, price):
        super().__init__(title, author, year)
        self.price = price

    def display_details(self):
        super().display_details()
        print(f"Price : Rs. {self.price}")


e1 = Ebook("Python Basics","Musab",2008,1500)


e1.display_details()
# Out:
# Book Details
# Title : Python Basics
# Author  : Musab
# Published Year  : 2008
# Price : Rs. 1500

# %%
# 8. Write a Python program that creates a class called 'Animal' with properties for species and sound. Include a method to make the animal's sound. 
# Create a subclass called 'Dog' that inherits from the 'Animal' class and adds an additional property for color.
# Override the make sound method to include the dog's color. 
# Create an instance of the 'Dog' class and make it make its sound.
class Animal:
    def __init__(self, species, sound):
        self.species = species
        self.sound = sound

    def make_sound(self):
        print(self.sound)


class Dog(Animal):
    def __init__(self, species, sound, color):
        super().__init__(species, sound)
        self.color = color

    def make_sound(self):
        print(f"My color is {self.color} and I say {self.sound}")


# Create object
d = Dog("German Shepherd", "Barkd", "Black")
d.make_sound()
# Out:
# My color is Black and I say Barkd

# %%
# # 9. Write a Python program that creates a class called Bank with properties for bank names and branches. 
# Include methods to add a branch, remove a branch, and display all branches. Create an instance of the Bank class and perform operations to add and 
# remove branches.
class Bank:
    def __init__(self, name):
        self.name = name
        self.br = []

    def add(self, b):
        self.br.append(b)
        print(b, "added")

    def rem(self, b):
        if b in self.br:
            self.br.remove(b)
            print(b, "removed")
        else:
            print(b, "not found")

    def show(self):
        print("Branches of", self.name)
        for i in self.br:
            print(i)


bk = Bank("Mexan")

bk.add("Karachi")
bk.add("Lahore")
bk.add("Islamabad")

bk.show()

bk.rem("Lahore")

bk.show()
# Out:
# Karachi added
# Lahore added
# Islamabad added
# Branches of Mexan
# Karachi
# Lahore
# Islamabad
# Lahore removed
# Branches of Mexan
# Karachi
# Islamabad

# %%
# 10. Write a Python program that creates a class called Product with properties for product ID, name, and price. 
# Include a method to calculate the total price by multiplying the price by the quantity. 
# Create a subclass called PersonalCareProduct that inherits from the Product class and adds an additional property for the warranty period. 
# Override the total price calculation method to include the warranty period.
# Create an instance of the PersonalCareProduct class and calculate its total price.


class Product:
    def __init__(self, product_id, name, price):
        self.product_id = product_id
        self.name = name
        self.price = price

    def total_price(self, quantity):
        if quantity <= 0:
            return 0
        return self.price * quantity


class PersonalCareProduct(Product):
    def __init__(self, product_id, name, price, warranty_cost):
        super().__init__(product_id, name, price)
        self.warranty_cost = warranty_cost

    def total_price(self, quantity):
        base_price = super().total_price(quantity)
        if self.warranty_cost > 0:
            return base_price + self.warranty_cost
        return base_price


product = PersonalCareProduct(
    product_id=301,
    name="Cream",
    price=2800,
    warranty_cost=600
)

final_price = product.total_price(2)
print("Total Price:", final_price)
# Out:
# Total Price: 6200

# %%
accounts = {}

# %%
# 11. Write a Python program that creates a class called BankAccount with properties for account number, account holder name, and balance.
# Include methods to deposit, withdraw, and transfer money between accounts.
# Create multiple instances of the BankAccount class and perform operations such as depositing, withdrawing, and transferring money.




class BankAccount:

    def create_account(self):
        name = input("Enter name: ")
        password = input("Enter password: ")
        acc_no = int(input("Enter account number: "))

        if acc_no in accounts:
            print("Account already exists")
        else:
            accounts[acc_no] = {
                "name": name,
                "password": password,
                "balance": 0
            }
            print("Account created successfully")

    def deposit(self):
        acc_no = int(input("Enter account number: "))
        if acc_no not in accounts:
            print("Account not found")
            return

        password = input("Enter password: ")
        if password != accounts[acc_no]["password"]:
            print("Wrong password")
            return

        amount = float(input("Enter amount to deposit: "))
        if amount <= 0:
            print("Invalid amount")
            return

        accounts[acc_no]["balance"] += amount
        print("Deposit successful")
        print("Balance:", accounts[acc_no]["balance"])

    def withdraw(self):
        acc_no = int(input("Enter account number: "))
        if acc_no not in accounts:
            print("Account not found")
            return

        password = input("Enter password: ")
        if password != accounts[acc_no]["password"]:
            print("Wrong password")
            return

        amount = float(input("Enter amount to withdraw: "))
        if amount <= 0:
            print("Invalid amount")
        elif amount > accounts[acc_no]["balance"]:
            print("Insufficient balance")
        else:
            accounts[acc_no]["balance"] -= amount
            print("Withdraw successful")
            print("Balance:", accounts[acc_no]["balance"])

    def transfer(self):
        from_acc = int(input("From account: "))
        to_acc = int(input("To account: "))

        if from_acc not in accounts or to_acc not in accounts:
            print("Invalid account number")
            return

        password = input("Enter password: ")
        if password != accounts[from_acc]["password"]:
            print("Wrong password")
            return

        amount = float(input("Enter transfer amount: "))
        if amount <= 0:
            print("Invalid amount")
        elif amount > accounts[from_acc]["balance"]:
            print("Not enough balance")
        else:
            accounts[from_acc]["balance"] -= amount
            accounts[to_acc]["balance"] += amount
            print("Transfer successful")
            print("Your balance:", accounts[from_acc]["balance"])


bank = BankAccount()

bank.create_account()
bank.deposit()
bank.withdraw()
bank.transfer()
# Out:
# Enter name:  Musab
# Enter password:  4
# Enter account number:  2
# Account created successfully
# Enter account number:  2
# Enter password:  4
# Enter amount to deposit:  100
# Deposit successful
# Balance: 100.0
# Enter account number:  2
# Enter password:  4
# Enter amount to withdraw:  12
# Withdraw successful
# Balance: 88.0
# From account:  1
# To account:  2
# Enter password:  123
# Enter transfer amount:  190
# Transfer successful
# Your balance: 710.0
