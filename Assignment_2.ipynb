# %%
# Assignment No.1 == Area
Lenght = int(input("Enter Lenght: "))
Width = int(input("Enter Width: "))
Area = Lenght * Width
print(Area)
# Out:
# Enter Lenght:  12
# Enter Width:  21
# 252

# %%
#Assignment No.2 == Circumfarence
Radius = int(input("Enter Radius: "))
Pie = 3.142
Circumfarence = 2 * Pie
print(Circumfarence)
# Out:
# Enter Radius:  12
# 6.284

# %%
#Assignment No.3 == Simple Intrest
Principle = int(input("Enter Principal: "))
Rate = int(input("Enter Rate: "))
Time = int(input("Enter Time: "))
Simple_Intrest = Principle * Rate * Time
print(Simple_Intrest)
# Out:
# Enter Principal:  12
# Enter Rate:  13
# Enter Time:  12
# 1872

# %%
#Assignment No.4 == Speed
Distance = int(input("Enter Distance in Km: "))
Time = int(input("Enter Time In Hr: "))
Speed = Distance / Time
print(Speed , "Km/H")
# Out:
# Enter Distance in Km:  12
# Enter Time In Hr:  12
# 1.0 Km/H

# %%
#Assignment No.5 == BMI Calculator
Weight = int(input("Enter Weight in Kg: "))
Height = int(input("Enter Height In M: "))
BMI = Weight / Height**2
print(BMI)
# Out:
# Enter Weight in Kg:  122
# Enter Height In M:  12
# 0.8472222222222222

# %%
#Assignment No.6 == Force
Mass = int(input("Enter Mass in Kg: "))
Acc = int(input("Enter Acceleratin In M/s: "))
F = Mass * Acc
print(F)
# Out:
# Enter Mass in Kg:  12
# Enter Acceleratin In M/s:  12
# 144

# %%
#Assignment No.7 == Compound Intrest
P = int(input("Enter Ammount: "))
R = int(input("Enter Principal Ammount: "))
N = int(input("Enter Numbr of Time Intrest is Compounded/Year: "))
T = int(input("Enter Time In Year"))
CI = P * (1 + R/N) ** (N - T)
print(CI)
# Out:
# Enter Ammount:  1
# Enter Principal Ammount:  22
# Enter Numbr of Time Intrest is Compounded/Year:  123
# Enter Time In Year 12
# 85581693.93529272

# %%
# Assignment No.8 == Perimeter
a = int(input("Enter Lenght Of 1st side"))
b = int(input("Enter Lenght Of 2nd side"))
c = int(input("Enter Lenght Of 3rd side"))
P = a + b + c
print(P)
# Out:
# Enter Lenght Of 1st side 12
# Enter Lenght Of 2nd side 21
# Enter Lenght Of 3rd side 31
# 64

# %%
#Assignment No.9 == SPHERE
Radius = int(input("Enter Radius: "))
Pie = 3.142
Sphere = (4/3) * Pie * (Radius)**3
print(Sphere)
# Out:
# Enter Radius:  67
# 1259996.4613333333

# %%
#Assignment No.10 == Kinetic Energy
M = int(input("Enter Mass In Kg"))
V = int(input("Enter Velocity im m/s"))
Kinectic = 1/2 * (M) * (V)**2
print(Kinectic)
# Out:
# Enter Mass In Kg 12
# Enter Velocity im m/s 32
# 6144.0

# %%
# Assignment No.12== Temp Coversion
Temp = int(input("Enter Temprature in Celsius"))
Farhenit = (9/5) * Temp + 32
print(Farhenit)
# Out:
# Enter Temprature in Celsius 123
# 253.4

# %%
#Assignment No.13 == Gravity
m1 = int(input("Enter 1st Obj Mass "))
m2 = int(input("Enter 2nd Obj Mass "))
m3 = int(input("Enter 3rd Obj Mass "))
r = int(input("Enter Radius"))
Force = m1 * m2 / r ** 2
print(force)
# Out:
# Enter 1st Obj Mass  112
# Enter 2nd Obj Mass  122
# Enter 3rd Obj Mass  1221
# Enter Radius 21

# %%
#Assignment No.14 == Volume Of Cylinder
r = int(input("Enter Radius: "))
h = int(input("Enter Height: "))
V = 3.142 * (r)** 2 * h
print(V)
# Out:
# Enter Radius:  12
# Enter Height:  13
# 5881.824

# %%
#Assignment No.15 == Pressure
F = int(input("Enter Force: "))
A = int(input("Enter Area: "))
P = F/A
print(P)
# Out:
# Enter Force:  12
# Enter Area:  23
# 0.5217391304347826

# %%
#Assignment No.16 == Electric Power
V = int(input("Enter Voltage: "))
C = int(input("Enter Cureent: "))
P = V/C
print(P)
# Out:
# Enter Voltage:  122
# Enter Cureent:  12
# 10.166666666666666

# %%
# Assignment No.17 == Perimiter Of Circle
r = int(input("Enter Radius"))
P = 2 * 3.142 * r
print(P)
# Out:
# Enter Radius 78
# 490.152

# %%
# Assignment No.18 == Future Value Of Saving
r = int(input("Enter Annual Intrest Rate"))
pv = int(input("ENter Present Value"))
t = int(input("Enter Time In Year"))
FV = pv * (1 + r)**t
print(FV)
# Out:
# Enter Annual Intrest Rate 12
# ENter Present Value 21
# Enter Time In Year 3
# 46137

# %%
# Assignment No.18 == Future Value Of Saving
f = int(input("Enter Force"))
d = int(input("Enter Distance "))
_0 = int(input("Enter 0: "))
Work_Force = f * d * _0
print(Work_Force)
# Out:
# Enter Force 12
# Enter Distance  12
# Enter 0:  3
# 432
